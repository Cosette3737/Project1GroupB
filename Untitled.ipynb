# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
#from Config import api_key
#from Config import gkey

# %%
stateevent2019=[]
stateevent2015=[]
stateevent2020=[]

medic_specs=[]
counts=[]
countryman=[]
typeevent=[]
manclass3=[]
manclass1=[]
x=0
url="https://api.fda.gov/device/classification.json?count=medical_specialty_description.exact"
response=requests.get(url).json()
print(json.dumps(response, indent=4))
for x in range(30):
    medic_specs.append(response['results'][x]['term'])
    counts.append(response['results'][x]['count'])
    x=x+1
    
#print (medic_specs)
#print(counts)
# Out:
# {
#     "meta": {
#         "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#         "terms": "https://open.fda.gov/terms/",
#         "license": "https://open.fda.gov/license/",
#         "last_updated": "2020-10-24"
#     },
#     "results": [
#         {
#             "term": "Unknown",
#             "count": 831
#         },
#         {
#             "term": "Gastroenterology, Urology",
#             "count": 538
#         },
#         {
#             "term": "Clinical Chemistry",
#             "count": 515
#         },
#         {
#             "term": "General, Plastic Surgery",
#             "count": 513
#         },
#         {
#             "term": "Microbiology",
#             "count": 468
#         },
#         {
# ...

# %%
specialty_dict={
    "Specialty":medic_specs,
    "Number":counts
}
specialty_df=pd.DataFrame(specialty_dict)
specialty_df.set_index(['Specialty'], inplace= True)
specialty_df

# %%
specialty_df.plot(kind='bar',title='Number of Devices per Medical Specialty', color='b', alpha=.75)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3c93d3c1506b> in <module>
# ----> 1 specialty_df.plot(kind='bar',title='Number of Devices per Medical Specialty', color='b', alpha=.75)
#       2 plt.show
#
# NameError: name 'specialty_df' is not defined

# %%
#Number of recalls per year 2015
devicetype15=[]
recalltype15=[]
url="https://api.fda.gov/device/enforcement.json?search=report_date:[20150101+TO+20151231]&limit=500"
response=requests.get(url).json()
#print(json.dumps(response, indent=4))

for x in range(500):
    stateevent2015.append(response['results'][x]['state'])
    devicetype15.append(response['results'][x]['product_type'])
    recalltype15.append(response['results'][x]['classification'])
    x=x+1
    #print(stateevent2015)

# %%
#Number of recalls per state per year 2019
devicetype19=[]
recalltype19=[]
url="https://api.fda.gov/device/enforcement.json?search=report_date:[20190101+TO+20191231]&limit=500"
response=requests.get(url).json()
#print(json.dumps(response, indent=4))

for x in range(500):
    stateevent2019.append(response['results'][x]['state'])
    devicetype19.append(response['results'][x]['product_type'])
    recalltype19.append(response['results'][x]['classification'])
    x=x+1

# %%
#Number of recalls per year 2020
devicetype20=[]
recalltype20=[]
url="https://api.fda.gov/device/enforcement.json?search=report_date:[20200101+TO+20201231]&limit=500"
response=requests.get(url).json()
print(json.dumps(response, indent=4))

for x in range(500):
    stateevent2020.append(response['results'][x]['state'])
    devicetype20.append(response['results'][x]['product_type'])
    recalltype20.append(response['results'][x]['classification'])
    x=x+1
# Out:
# {
#     "meta": {
#         "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#         "terms": "https://open.fda.gov/terms/",
#         "license": "https://open.fda.gov/license/",
#         "last_updated": "2020-10-24",
#         "results": {
#             "skip": 0,
#             "limit": 500,
#             "total": 2440
#         }
#     },
#     "results": [
#         {
#             "country": "United States",
#             "city": "Tustin",
#             "address_1": "2441 Michelle Dr",
#             "reason_for_recall": "Bolts holding the longitudinal movement of catheterization tables may be loose, which may lead to table surface/top tilting.",
#             "address_2": "",
#             "product_quantity": "24",
# ...

# %%
print(len(stateevent2020))
print(len(stateevent2019))
print(len(stateevent2015))
# Out:
# 500
# 500
# 500

# %%
stateevent_dict={
    "Events in 2015":stateevent2015,
    "Events in 2019":stateevent2019,
    "Events in 2020":stateevent2020,
}
stateevent_df=pd.DataFrame(stateevent_dict)
stateevent_df
# Out:
#     Events in 2015 Events in 2019 Events in 2020
# 0               CT             NJ             CA
# 1               PR             PA             OR
# 2               CA                            FL
# 3                              NY             OH
# 4               WA             TX
# ..             ...            ...            ...
# 495             IN             PA             MD
# 496             GA             MN             AZ
# 497             CT             MA
# 498             CA             CA             MA
# 499             CA             IN             CT
#
# [500 rows x 3 columns]

# %%
clean_data=stateevent_df["Events in 2015"].nunique()
clean_data
clean_data1=stateevent_df["Events in 2019"].nunique()
clean_data1
clean_data2=stateevent_df["Events in 2020"].nunique()
print(clean_data2)
# Out:
# 29

# %%
stateeventclean2015 = stateevent_df['Events in 2015'].value_counts().head()
stateeventclean2020 = stateevent_df['Events in 2020'].value_counts().head()
stateeventclean2019 = stateevent_df['Events in 2019'].value_counts().head()
#print(stateeventclean2015)
#print(stateeventclean2020)
#print(stateeventclean2019)
stateeventclean2015.plot(kind='bar',title='Events in 2015 per State', color='b', alpha=.75)
plt.show
#stateeventclean2020.plot(kind='bar',title='Events in 2020', color='b', alpha=.75)
#plt.show
#stateeventclean2019.plot(kind='bar',title='Events in 2019', color='b', alpha=.75)
#plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
stateeventclean2020.plot(kind='bar',title='Events in 2020', color='b', alpha=.75)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
stateeventclean2019.plot(kind='bar',title='Events in 2019', color='b', alpha=.75)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
devicetype_dict={
    "Type of events in 2015":devicetype15,
    "Type of events in 2019":devicetype19,
    "Type of events in 2020":devicetype20,
}
devicetype_df=pd.DataFrame(devicetype_dict)
#devicetype_df

# %%
recalltype_dict={
    "Recall types in 2015":recalltype15,
    "Recall types in 2019":recalltype19,
    "Recall types in 2020":recalltype20,
}
recalltype_df=pd.DataFrame(recalltype_dict)
#recalltype_df

# %%
countrycount=[]
#Number of devices per country
url="https://api.fda.gov/device/510k.json?count=country_code"
response=requests.get(url).json()
print(json.dumps(response, indent=4))
#countryman.append(response['results'][0]['term'])
for x in range(50):
    countryman.append(response['results'][x]['term'])
    countrycount.append(response['results'][x]['count'])
   
    #print(stateevent2015)
# Out:
# {
#     "meta": {
#         "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#         "terms": "https://open.fda.gov/terms/",
#         "license": "https://open.fda.gov/license/",
#         "last_updated": "2020-10-24"
#     },
#     "results": [
#         {
#             "term": "US",
#             "count": 137658
#         },
#         {
#             "term": "CN",
#             "count": 2432
#         },
#         {
#             "term": "CA",
#             "count": 1947
#         },
#         {
#             "term": "DE",
#             "count": 1840
#         },
#         {
#             "term": "TW",
#             "count": 1592
#         },
#         {
#             "term": "GB",
#             "count": 1540
#         },
#         {
# ...

# %%
print(len(countryman))
print(len(countrycount))
# Out:
# 50
# 50

# %%
#Number of events per country
countryman_dict={
    "countryevent":countryman,
    "Number of devices manufacutred per country":countrycount
}
countryman_df=pd.DataFrame(countryman_dict)
countryman_df.head()

labels = ["US", "CN", "CA","DE", "TW"]
sizes = [137658,2432,1947,1840,1592]
colors = ["green", "red", "blue", "yellow","orange"]
explode = (0,0,0,0,0)
fig2 = plt.subplots(figsize=(15, 10))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('Events per Country',fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Events per Country')

# %%
#Adverse Events with xray devices
radman=[]
numberpt=[]
devicetype=[]
medicalspecrad=[]
radstate=[]


url="https://api.fda.gov/device/event.json?search=device.generic_name:x-ray&limit=100"
response=requests.get(url).json()
print(json.dumps(response, indent=4))
for x in range(200):
    #print(json.dumps(response['results'], indent=4))
    if 'manufacturer_d_name' in response['results'][x]['device'][0]:
        radman.append(response['results'][x]['device'][0]['manufacturer_d_name'])
    else:
        radman.append("not listed")
        
    if 'generic_name' in response['results'][x]['device'][0]:
        radstate.append(response['results'][x]['device'][0]['generic_name'])
    else:
        radstate.append("not listed")
    
    if 'number_patients_in_event' in response['results'][x]:
        numberpt.append(response['results'][x]['number_patients_in_event'])
    else:
        numberpt.append("not listed")
    print(json.dumps(response['results'][x]['device'][0], indent=4))    
    if 'implant_flag' in response['results'][x]['device'][0]:    
        devicetype.append(response['results'][x]['device'][0]['implant_flag'])
    else:
        devicetype.append("not listed")
        
    if 'medical_specialty_description' in response['results'][x]['device'][0]['openfda']:
        medicalspecrad.append(response['results'][x]['device'][0]['openfda']['medical_specialty_description'])
    else:
        medicalspecrad.append("not listed")
# Out:
# {
#     "meta": {
#         "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#         "terms": "https://open.fda.gov/terms/",
#         "license": "https://open.fda.gov/license/",
#         "last_updated": "2020-10-25",
#         "results": {
#             "skip": 0,
#             "limit": 100,
#             "total": 121805
#         }
#     },
#     "results": [
#         {
#             "manufacturer_contact_zip_ext": "",
#             "manufacturer_g1_address_2": "",
#             "event_location": "",
#             "report_to_fda": "",
#             "manufacturer_contact_t_name": "",
#             "manufacturer_contact_state": "UT",
#             "manufacturer_link_flag": "Y",
#             "manufacturer_g1_city": "",
# ...

# %%
xray_dict={
    "Manufacturer":radman,
    "Generic Name":radstate,
    "Medical Specialty":medicalspecrad
}
xray_df=pd.DataFrame(xray_dict)
xray_df.head()
# Out:
#                                Manufacturer  \
# 0               GE OEC MEDICAL SYSTEMS INC.
# 1  SIEMENS SHENZHEN MAGNETIC RESONANCE LTD.
# 2                      SANMINA -SCI SYSTEMS
# 3     MEDTRONIC NAVIGATION, INC (LITTLETON)
# 4     MEDTRONIC NAVIGATION, INC (LITTLETON)
#
#                                         Generic Name Medical Specialty
# 0                                 FLUOROSCOPIC X-RAY         Radiology
# 1           INTERVENTIONAL FLUOROSCOPIC X-RAY SYSTEM         Radiology
# 2           INTERVENTIONAL FLUOROSCOPIC X-RAY SYSTEM         Radiology
# 3  IMAGE-INTENSIFIED FLUOROSCOPIC X-RAY SYSTEM, M...         Radiology
# 4  IMAGE-INTENSIFIED FLUOROSCOPIC X-RAY SYSTEM, M...         Radiology

# %% [raw]
# manufactotal = xray_df["Manufacturer"].nunique()
# manufactotal = manufactotal.value_counts
# generictotal = xray_df["Generic Name"].value_counts
#
# medicalspecrad = xray_df["Medical Specialty"].value_counts
#
# print(manufactotal)

# %%
radman.plot(kind='bar',title='Manufacturer in Radiology Recall', color='b', alpha=.75)
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-c1a0d47094dd> in <module>
# ----> 1 radman.plot(kind='bar',title='Manufacturer in Radiology Recall', color='b', alpha=.75)
#       2 plt.show
#
# AttributeError: 'list' object has no attribute 'plot'

# %%
print(medicalspecrad)
# Out:
# ['Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'General, Plastic Surgery', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiology', 'Radiol
# ...

# %%
manufactotal_df.plot(kind='bar',title='Manufacturer in Radiology Recall', color='b', alpha=.75)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-7c00a961fcfe> in <module>
# ----> 1 manufactotal_df.plot(kind='bar',title='Manufacturer in Radiology Recall', color='b', alpha=.75)
#       2 plt.show
#
# NameError: name 'manufactotal_df' is not defined

# %%
generictotal.plot(kind='bar',title='Equipment involved in Radiology Recall', color='b', alpha=.75)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-83d68a8fb22e> in <module>
# ----> 1 generictotal.plot(kind='bar',title='Equipment involved in Radiology Recall', color='b', alpha=.75)
#       2 plt.show
#
# NameError: name 'generictotal' is not defined

# %%
devicetotal.plot(kind='bar',title='Equipment involved in Radiology Recall', color='b', alpha=.75)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-92991374bf27> in <module>
# ----> 1 devicetotal.plot(kind='bar',title='Equipment involved in Radiology Recall', color='b', alpha=.75)
#       2 plt.show
#
# NameError: name 'devicetotal' is not defined

# %%
#Adverse count of event types-exray devices
radevent=[]
radeventcount=[]
devicetype=[]

url="https://api.fda.gov/device/event.json?search=device.generic_name:x-ray&count=event_type.exact"
response=requests.get(url).json()
for x in range(5):
    radevent.append(response['results'][x]['term'])
    radeventcount.append(response['results'][x]['count'])
    x=x+1
print(json.dumps(response, indent=4))
# Out:
# {
#     "meta": {
#         "disclaimer": "Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.",
#         "terms": "https://open.fda.gov/terms/",
#         "license": "https://open.fda.gov/license/",
#         "last_updated": "2020-10-25"
#     },
#     "results": [
#         {
#             "term": "Malfunction",
#             "count": 111157
#         },
#         {
#             "term": "Injury",
#             "count": 9726
#         },
#         {
#             "term": "Other",
#             "count": 392
#         },
#         {
#             "term": "No answer provided",
#             "count": 292
#         },
#         {
#             "term": "Death",
#             "count": 238
#         }
#     ]
# }

# %%
rad_dict={
    "Type of event":radevent,
    "Count of events":radeventcount
}
rad_dict_df=pd.DataFrame(rad_dict)
rad_dict_df.set_index(['Type of event'], inplace= True)
rad_dict_df
# Out:
#                     Count of events
# Type of event
# Malfunction                  111157
# Injury                         9726
# Other                           392
# No answer provided              292
# Death                           238

# %%
labels=["Malfunction", "Injury","Death"]
sizes = [111157,9726,238]
colors = [ "green", "orange","Red"]
explode = (0,0,0)
fig2 = plt.subplots(figsize=(5, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct="%1.1f%%", shadow=False, startangle=140)
plt.title('Adverse Event',fontsize = 20)
plt.ylabel('Value',fontsize = 14)
plt.axis("equal")
# Out:
# (-1.1029566239761575,
#  1.1077018346657406,
#  -1.107523601950493,
#  1.100929404640646)

# %%
#different manufactures per class type3
class3man=[]
class3count=[]
url="https://api.fda.gov/device/510k.json?search=openfda.device_class:3&count=applicant.exact"
response = requests.get(url).json()

#print(json.dumps(response, indent=4))
for x in range(100):
    class3man.append(response['results'][x]['term'])
    class3count.append(response['results'][x]['count'])

# %%
#different manufactures per class type1
class1man=[]
class1count=[]
url="https://api.fda.gov/device/510k.json?search=openfda.device_class:1&count=applicant.exact"
response = requests.get(url).json()
#print(json.dumps(response, indent=4))
for x in range(100):
    class1man.append(response['results'][x]['term'])
    class1count.append(response['results'][x]['count'])

# %%
class2man=[]
class2count=[]
url="https://api.fda.gov/device/510k.json?search=openfda.device_class:2&count=applicant.exact"
response = requests.get(url).json()
#print(json.dumps(response, indent=4))
for x in range(100):
    class2man.append(response['results'][x]['term'])
    class2count.append(response['results'][x]['count'])

# %%
classman2_dict={
    "Manufacturers Class 2":class2man,
    "Number of devices Class 2":class2count,
}
classman2_df=pd.DataFrame(classman2_dict).head()
classman2_df.set_index(['Manufacturers Class 2'], inplace= True)
classman2_df
# Out:
#                                      Number of devices Class 2
# Manufacturers Class 2
# ABBOTT LABORATORIES                                        676
# C.R. BARD, INC.                                            523
# SIEMENS MEDICAL SOLUTIONS USA, INC.                        497
# BAXTER HEALTHCARE CORP.                                    423
# BOSTON SCIENTIFIC CORP.                                    419

# %%
classman3_dict={
    "Manufacturers Class 3":class3man,
    "Number of devices Class 3":class3count,
}
classman3_df=pd.DataFrame(classman3_dict).head()
classman3_df.set_index(['Manufacturers Class 3'], inplace= True)
classman3_df

labels = ["Abbot Laboratories", "C.R. Bard, inc","Siemens Medical Soulutions USA, INC", "Baxter Healthcare Corp", "Boston Scientific Corp"]
sizes = [676,523,497,]
colors = ["yellow", "blue", "green"]
explode = (0,0,0)
fig2 = plt.subplots(figsize=(15, 10))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('Devices Classification',fontsize = 20)
plt.ylabel('Sex',fontsize = 14)
plt.axis("equal")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-0d2e709004c3> in <module>
#      12 explode = (0,0,0)
#      13 fig2 = plt.subplots(figsize=(15, 10))
# ---> 14 plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct="%1.1f%%", shadow=True, startangle=140)
#      15 plt.title('Devices Classification',fontsize = 20)
#      16 plt.ylabel('Sex',fontsize = 14)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# ...

# %%
classman1_dict={
    "Manufacturers Class 1":class1man,
    "Number of devices Class 1":class1count,
}
classman1_df=pd.DataFrame(classman1_dict).head()
classman1_df.set_index(['Manufacturers Class 1'], inplace= True)
classman1_df
# Out:
#                                                     Number of devices Class 1
# Manufacturers Class 1
# FRED SAMMONS, INC.                                                        263
# BD BECTON DICKINSON VACUTAINER SYSTEMS PREANALYTIC                        214
# BIO-RAD                                                                   177
# ABBOTT LABORATORIES                                                       165
# ACUMEDIA MANUFACTURERS, INC.                                              165

# %%
# caluculating the total number of devices accounted for
Total_class1 = sum(classman1_df["Number of devices Class 1"])
Total_class2 = sum(classman2_df["Number of devices Class 2"])
Total_class3 = sum(classman3_df["Number of devices Class 3"])
Grand_total = Total_class1 + Total_class2 + Total_class3
Grand_total
# Out:
# 4014

# %%
percent_class1 = (Total_class1/Grand_total)*100
print('Percent of class 1: '+str(round(percent_class1))+'%')
5:50
percent_class2 = (Total_class2/Grand_total)*100
print('Percent of class 2: '+str(round(percent_class2))+'%')
5:51
percent_class3 = (Total_class3/Grand_total)*100
print('Percent of class 3: '+str(round(percent_class3))+'%')
# Out:
#   File "<ipython-input-39-cbbc833f5902>", line 3
#     5:50
#         ^
# SyntaxError: illegal target for annotation

# %%
labels = ["Class 1", "Class 2", "Class 3"]
sizes = [25,63,12]
colors = ["yellow", "blue", "green"]
explode = (0,0,0)
fig2 = plt.subplots(figsize=(15, 10))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct="%1.1f%%", shadow=True, startangle=140)
plt.title('Devices Classification',fontsize = 20)
plt.ylabel('Value',fontsize = 14)
plt.axis("equal")

# %%
classman1_df.plot(kind='bar',title='Number of Devices per Manufacturer', color='b', alpha=.75)
plt.show

# %%
classman3_df.plot(kind='bar',title='Number of Devices per Manufacturer', color='b', alpha=.75)
plt.show

# %%
#open device recalls
recallspecialty=[]

devicetypes=[]
device_class=[]

url="https://api.fda.gov/device/recall.json?search=_missing_:marketing_end_date&limit=250"
response = requests.get(url).json()
print(json.dumps(response, indent=4))
for x in range(175):
    recallspecialty.append(response['results'][x]['openfda']['medical_specialty_description'])
    devicetypes.append(response['results'][x]['openfda']['device_name'])
    device_class.append(response['results'][x]['openfda']['device_class'])

# %%
recall_info_dict={
    "Medical Specialty":recallspecialty,
    "Type of Device": devicetypes,
    "Device Class":device_class
}
recall_info_df=pd.DataFrame(recall_info_dict)
#recall_info_df.set_index(['Medical Specialty'])
recall_info_df

# %%
specialty_open=recall_info_df["Medical Specialty"].value_counts()
specopen=specialty_open.head()
specopen

specopen.plot(kind='bar',title='Open recalls for each specialty', color='b', alpha=.75)
plt.show

# %%
type_open=recall_info_df["Type of Device"].value_counts()
types_open=type_open.head()
types_open
types_open.plot(kind='bar',title='Open recalls for each specialty', color='b', alpha=.75)
plt.show

# %%
open_class=recall_info_df["Device Class"].value_counts()
open_class

# %%
import gmaps
gkey="AIzaSyBbtf-cQpfWW8agzsIEXb5W9dIknS9ODXg"
gmaps.configure(api_key=gkey)

# %%
site_lat = [37.0902,35.8617,56.1304,56.2639,23.6978]
site_lon = [95.7129,104.1954,106.3468,9.5018,120.9605]
locations_name = ['US', 'CN', 'CA', 'DE', 'TW']
locations = [(site_lat[i], site_lon[i]) for i in range(0, len(site_lat))]
sizes = [137658,2432,1947,1840,1592]
print(locations)
# Plot Heatmap
fig = gmaps.figure()
# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=sizes,
                                 dissipating=False, max_intensity=100,
                                 point_radius=3)
# Add layer
fig.add_layer(heat_layer)
# Display figure
fig
